# %%
import pandas as pd

# %%
dataset = pd.read_csv("kidney_disease.csv")

# %%
dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
# Checking Null values
dataset.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
# Finding Quantitative and Qualitative columns 
from Univariate import univariate
qual,quan = univariate.QuanQual(dataset)

# %%
quan
# Out:
# ['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']

# %%
qual
# Out:
# ['rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'pcv',
#  'wc',
#  'rc',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %% [markdown]
# # Quantitaive data PreProcessing

# %%
dataset[quan].isnull().sum()
# Out:
# id       0
# age      9
# bp      12
# sg      47
# al      46
# su      49
# bgr     44
# bu      19
# sc      17
# sod     87
# pot     88
# hemo    52
# dtype: int64

# %%
dataset[quan].columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot',
#        'hemo'],
#       dtype='object')

# %%
# Impute 'age' and 'hemo' using mean (normal distribution)
# other quantitative columns using median (due to high skewness and discrete clinical scales)
mean_impute = ['age','hemo']
median_impute = ['bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot']

# %%
# Mean Imputation
dataset[mean_impute] = dataset[mean_impute].fillna(dataset[mean_impute].mean())

# Median Imputaion
dataset[median_impute] = dataset[median_impute].fillna(dataset[median_impute].median())

# %%
dataset[quan].isnull().sum()
# Out:
# id      0
# age     0
# bp      0
# sg      0
# al      0
# su      0
# bgr     0
# bu      0
# sc      0
# sod     0
# pot     0
# hemo    0
# dtype: int64

# %% [markdown]
# # Qualitative Data PreProcessing

# %%
dataset[qual].isnull().sum()
# Out:
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
dataset[qual].columns
# Out:
# Index(['rbc', 'pc', 'pcc', 'ba', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
# Use 'Unknown' category for columns with high null counts (rbc, pc) and mode imputation for the rest
high_null = ['rbc','wc', 'rc','pc','pcv']
low_null = ['pcc', 'ba','htn', 'dm', 'cad','appet', 'pe', 'ane']

# %%
# Replace Unknown 
dataset[high_null] = dataset[high_null].fillna("Unknown")

# Mode Imputation
dataset[low_null] = dataset[low_null].fillna(dataset[low_null].mode().iloc[0])

# %%
dataset[qual].isnull().sum()
# Out:
# rbc               0
# pc                0
# pcc               0
# ba                0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
dataset
# Out:
#       id   age    bp     sg   al   su      rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0  Unknown    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0  Unknown    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0   normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0   normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0   normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...      ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0   normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0   normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0   normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0   normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0   normal    normal  notpresent
#
#              ba  ...  pcv    wc       rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
dataset.isna().sum()
# Out:
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64
