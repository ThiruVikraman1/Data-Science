# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from Univariate import univariate
un = univariate

# %%
un.QuanQual(dataset)
# Out:
# (['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'],
#  ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'])

# %%
qual,quan = un.QuanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
table = un.Descriptive_Table(dataset,quan)

# %%
un.Frequency("ssc_p",dataset)
# Out:
#      Unique Values  Frequency  Relative Frequency     Cusum
# 0            62.00         11            0.106796  0.106796
# 1            63.00         10            0.097087  0.203883
# 2            67.00          9            0.087379  0.291262
# 3            73.00          9            0.087379  0.378641
# 4            52.00          9            0.087379  0.466019
# ..             ...        ...                 ...       ...
# 98           55.68          1            0.009709  2.048544
# 99           41.00          1            0.009709  2.058252
# 100          83.33          1            0.009709  2.067961
# 101          43.00          1            0.009709  2.077670
# 102          80.60          1            0.009709  2.087379
#
# [103 rows x 4 columns]

# %%
un.Frequency("hsc_p",dataset)
# Out:
#     Unique Values  Frequency  Relative Frequency     Cusum
# 0           63.00         14            0.144330  0.144330
# 1           62.00         12            0.123711  0.268041
# 2           60.00          9            0.092784  0.360825
# 3           67.00          9            0.092784  0.453608
# 4           64.00          8            0.082474  0.536082
# ..            ...        ...                 ...       ...
# 92          77.60          1            0.010309  2.175258
# 93          70.20          1            0.010309  2.185567
# 94          61.40          1            0.010309  2.195876
# 95          61.33          1            0.010309  2.206186
# 96          42.00          1            0.010309  2.216495
#
# [97 rows x 4 columns]

# %%
un.Frequency("degree_p",dataset)
# Out:
#     Unique Values  Frequency  Relative Frequency     Cusum
# 0           65.00         20            0.224719  0.224719
# 1           66.00         13            0.146067  0.370787
# 2           72.00         12            0.134831  0.505618
# 3           64.00         11            0.123596  0.629213
# 4           58.00          9            0.101124  0.730337
# ..            ...        ...                 ...       ...
# 84          64.80          1            0.011236  2.370787
# 85          56.30          1            0.011236  2.382022
# 86          91.00          1            0.011236  2.393258
# 87          56.87          1            0.011236  2.404494
# 88          77.60          1            0.011236  2.415730
#
# [89 rows x 4 columns]

# %%
un.Outlier_Columns(table,quan)
# Out:
# (['hsc_p'], ['hsc_p', 'degree_p', 'salary'])

# %%
Lesser_outlier,Greater_outlier = un.Outlier_Columns(table,quan)

# %%
Lesser_outlier
# Out:
# ['hsc_p']

# %%
Greater_outlier
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
un.Replace_Outliers(Lesser_outlier,Greater_outlier,table,dataset)

# %%
table = un.Descriptive_Table(dataset,quan)

# %%
Lesser_outlier,Greater_outlier = un.Outlier_Columns(table,quan)

# %%
Lesser_outlier
# Out:
# []

# %%
Greater_outlier
# Out:
# []

# %%
table
# Out:
#                 sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean            108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median          108.0       67.0       65.0       66.0       71.0       62.0
# Mode                1       62.0       63.0       65.0       60.0       56.7
# Q1:25%           54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%          108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%          161.5       75.7       73.0       72.0       83.5     66.255
# 99%            212.86       87.0     91.129      83.86       97.0    76.1142
# Q4:100%         215.0       89.4      91.15       88.5       98.0      77.89
# IQR             107.0       15.1       12.1       11.0       23.5       8.31
# 1.5_Rule        160.5      22.65      18.15       16.5      35.25     12.465
# Lesser_range   -106.0      37.95      42.75       44.5      24.75      45.48
# ...
